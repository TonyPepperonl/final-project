# %% [markdown]
# Preproccessing

# %% [markdown]
# https://www.kaggle.com/datasets/lainguyn123/student-performance-factors

# %%
import pandas as pd
df=pd.read_csv("StudentPerformanceFactors.csv")
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# Understanding the data

# %%
df.dtypes
# Out:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %% [markdown]
# Cleansing null values

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
df['Teacher_Quality'] = df['Teacher_Quality'].fillna(df['Teacher_Quality'].mode()[0]) 
df['Parental_Education_Level'] = df['Parental_Education_Level'].fillna(df['Parental_Education_Level'].mode()[0]) 
df['Distance_from_Home'] = df['Distance_from_Home'].fillna(df['Distance_from_Home'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %% [markdown]
# Dropping irrelevant columns

# %%
df = df.drop(columns=['Gender', 'Learning_Disabilities','Distance_from_Home', 'Previous_Scores', 'Peer_Influence'])

# %% [markdown]
# Renaming columns

# %%
df = df.rename(columns={'Hours_Studied': 'Hours Studied', 'Attendance': 'Attendance','Parental_Involvement': 'Parental Involvement', 'Access_to_Resources': 'Resource Access','Extracurricular_Activities': 'Extracurricular Activities', 'Sleep_Hours': 'Sleep Hours','Motivation_Level': 'Motivation Level', 'Internet_Access': 'Internet Access','Tutoring_Sessions': 'Tutoring Sessions', 'Family_Income': 'Family Income', 'Teacher_Quality': 'Teacher Quality', 'School_Type': 'School Type', 'Physical_Activity': 'Physical Activity', 'Parental_Education_Level': 'Parental Education Level', 'Exam_Score': 'Exam Score'})

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Attendance', 'Parental Involvement',
#        'Resource Access', 'Extracurricular Activities', 'Sleep Hours',
#        'Motivation Level', 'Internet Access', 'Tutoring Sessions',
#        'Family Income', 'Teacher Quality', 'School Type', 'Physical Activity',
#        'Parental Education Level', 'Exam Score'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    Hours Studied  Attendance Parental Involvement Resource Access  \
# 0             23          84                  Low            High
# 1             19          64                  Low          Medium
# 2             24          98               Medium          Medium
# 3             29          89                  Low          Medium
# 4             19          92               Medium          Medium
# 5             19          88               Medium          Medium
# 6             29          84               Medium             Low
# 7             25          78                  Low            High
# 8             17          94               Medium            High
# 9             23          98               Medium          Medium
#
#   Extracurricular Activities  Sleep Hours Motivation Level Internet Access  \
# 0                         No            7              Low             Yes
# 1                         No            8              Low             Yes
# ...

# %% [markdown]
# Splitting the data based on data types and One-Hot encoding

# %%
df.dtypes
# Out:
# Hours Studied                  int64
# Attendance                     int64
# Parental Involvement          object
# Resource Access               object
# Extracurricular Activities    object
# Sleep Hours                    int64
# Motivation Level              object
# Internet Access               object
# Tutoring Sessions              int64
# Family Income                 object
# Teacher Quality               object
# School Type                   object
# Physical Activity              int64
# Parental Education Level      object
# Exam Score                     int64
# dtype: object

# %%
cat_col = ['Parental Involvement','Resource Access', 'Motivation Level', 'Family Income', 'Teacher Quality', "Parental Education Level"]
cat_df = df[cat_col]
df = pd.get_dummies(df.drop(*[cat_col], axis=1), drop_first=True)
df.head()
# Out:
#    Hours Studied  Attendance  Sleep Hours  Tutoring Sessions  \
# 0             23          84            7                  0
# 1             19          64            8                  2
# 2             24          98            7                  2
# 3             29          89            8                  1
# 4             19          92            6                  3
#
#    Physical Activity  Exam Score  Extracurricular Activities_Yes  \
# 0                  3          67                           False
# 1                  4          61                           False
# 2                  4          74                            True
# 3                  4          71                            True
# 4                  4          70                            True
#
#    Internet Access_Yes  School Type_Public
# 0                 True                True
# 1                 True                True
# 2                 True                True
# ...

# %%
for col in cat_df:
    if cat_df[col].str.contains("Low").any():
        levels = {"Low": 0, "Medium": 1, "High": 2}
    else:
        levels = {"High School": 0, "College": 1, "Postgraduate": 2}

    cat_df[col] = cat_df[col].map(levels)

cat_df.head()
# Out:
#    Parental Involvement  Resource Access  Motivation Level  Family Income  \
# 0                     0                2                 0              0
# 1                     0                1                 0              1
# 2                     1                1                 1              1
# 3                     0                1                 1              1
# 4                     1                1                 1              1
#
#    Teacher Quality  Parental Education Level
# 0                1                         0
# 1                1                         1
# 2                1                         2
# 3                1                         0
# 4                2                         1

# %%
df = pd.concat([df, cat_df], axis=1)
df.astype(int)
df.head()
# Out:
#    Hours Studied  Attendance  Sleep Hours  Tutoring Sessions  \
# 0             23          84            7                  0
# 1             19          64            8                  2
# 2             24          98            7                  2
# 3             29          89            8                  1
# 4             19          92            6                  3
#
#    Physical Activity  Exam Score  Extracurricular Activities_Yes  \
# 0                  3          67                           False
# 1                  4          61                           False
# 2                  4          74                            True
# 3                  4          71                            True
# 4                  4          70                            True
#
#    Internet Access_Yes  School Type_Public  Parental Involvement  \
# 0                 True                True                     0
# 1                 True                True                     0
# ...

# %%
clean_df = df 
clean_df
# Out:
#       Hours Studied  Attendance  Sleep Hours  Tutoring Sessions  \
# 0                23          84            7                  0
# 1                19          64            8                  2
# 2                24          98            7                  2
# 3                29          89            8                  1
# 4                19          92            6                  3
# ...             ...         ...          ...                ...
# 6602             25          69            7                  1
# 6603             23          76            8                  3
# 6604             20          90            6                  3
# 6605             10          86            6                  2
# 6606             15          67            9                  0
#
#       Physical Activity  Exam Score  Extracurricular Activities_Yes  \
# 0                     3          67                           False
# ...

# %%
clean_df.to_csv("cleaned_data.csv", index=False)
